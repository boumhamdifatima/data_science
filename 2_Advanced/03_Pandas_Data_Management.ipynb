# %% [markdown]
# # Pandas Data Management
#
# Load data.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df.tail(4)
# Out:
#           job_title_short                                          job_title  \
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# ...

# %%
df.sample(6)
# Out:
#               job_title_short                                job_title  \
# 440246         Data Scientist                           Data Scientist
# 83806            Data Analyst                         Sr. Data Analyst
# 326273         Data Scientist                    Manager, Data Science
# 661154  Senior Data Scientist                    Senior Data Scientist
# 656182          Data Engineer  Data Center Support Engineer in Germany
# 176625         Data Scientist                           Data Scientist
#
#                                              job_location         job_via  \
# 440246                        Bengaluru, Karnataka, India      via Indeed
# 83806                                         Chicago, IL      via Indeed
# 326273                                       Thornton, CO  via JobzNearBy
# 661154                                           Anywhere    via LinkedIn
# 656182  Caltanissetta, Free municipal consortium of Ca...       via BeBee
# ...

# %%
df.sample(5, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
# 425158   Amsterdam, Netherlands   via NBC4i Jobs         Full-time
#
# ...

# %% [markdown]
# # Copy
#
# Recall from the last lesson, when we filled in missing values for median salary.
#
# Here let's make a new dataframe `df_altered` and only make changes to it.

# %%
# DataFrame Copy
df_copied = df.copy()

# DataFrame assigned
df_assigned = df

print('ID of df:                ', id(df))
print('ID of df_copied:         ', id(df_copied))
print('ID of df_assigned:       ', id(df_assigned))
# Out:
# ID of df:                 2516211201936
# ID of df_copied:          2516119527120
# ID of df_assigned:        2516211201936

# %%
# Create new dataframe
df_altered = df_copied

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Let's fill in missing values with the median value.

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %% [markdown]
# Now let's inspect the altered DataFrame.

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# hat was good...
#
# But what about the original(copied)...

# %%
df_copied.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Well both the variables of df_copied and df_altered are referencing the same DataFrame.
#
# Instead we can use the .copy() method
#
# copy(): Copy a DataFrame.

# %%
df_copied = df.copy()
df_altered = df_copied.copy()

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %% [markdown]
# Now let's inspect the altered DataFrame.

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_copied.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Now that we've created a copy of our data, we want to start our analysis. But if we have a large set of data we only want to take a subset of data to make it more manageable.
